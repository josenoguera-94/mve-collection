# %% [markdown]
# # First execution
#
# If you need to select the kernel, select **.venv/bin/python**.

# %% [markdown]
# # Databricks Local Analysis
# This notebook demonstrates how to interact with the local Spark environment and the Hive Metastore.

# %%
from src.databricks_shim.connect import get_spark_session

spark = get_spark_session("Notebook_Data_Analysis")
print("Spark Session Active")
# Out:
# ⚡ Initializing Local Spark Session (Databricks Emulator)...
# 26/01/05 19:47:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark Session Active

# %% [markdown]
# ## Query the Silver Table
# We can query the table created by the ETL job directly using SQL.

# %%
table_name = "sales.products_silver"
spark.sql(f"SELECT * FROM {table_name}").show()
# Out:
# 26/01/05 19:47:08 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 26/01/05 19:47:10 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 26/01/05 19:47:10 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 26/01/05 19:47:11 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 26/01/05 19:47:11 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore UNKNOWN@172.18.0.5
# 26/01/05 19:47:11 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# 26/01/05 19:47:15 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...
